# %% [markdown]
# ## Comparing Apple and Samsung Stock Performance

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
apple_stock = yf.download("AAPL", start = "2022-01-01", end = "2023-01-01")
samsung_stock = yf.download("SSNLF", start = "2022-01-01", end = "2023-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
apple_stock
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.724579  \
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  177.443542
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.723602
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  169.840240
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.008102
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  130.959961
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.142441
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.179688
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.725311
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.043121
#
#                Volume
# Date
# 2022-01-03  104487900
# 2022-01-04   99310400
# 2022-01-05   94537600
# ...

# %%
samsung_stock
# Out:
#                  Open       High        Low      Close     Adj Close  Volume
# Date
# 2022-01-03  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# 2022-01-04  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# 2022-01-05  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# 2022-01-06  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# 2022-01-07  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# ...               ...        ...        ...        ...           ...     ...
# 2022-12-23  40.599899  40.599899  40.599899  40.599899 -1.242691e+06       0
# 2022-12-27  40.599899  40.599899  40.599899  40.599899 -1.242691e+06       0
# 2022-12-28  40.599899  40.599899  40.599899  40.599899  1.574692e+05       0
# 2022-12-29  40.599899  40.599899  40.599899  40.599899  1.574692e+05       0
# 2022-12-30  40.599899  40.599899  40.599899  40.599899  1.574692e+05       0
#
# [251 rows x 6 columns]

# %% [markdown]
# ## Daily Return Calculation and Visualization
#
# #### Change of stock price over a day

# %%
apple_stock["Daily_Return"] = apple_stock["Adj Close"].pct_change()
samsung_stock["Daily_Return"] = samsung_stock["Adj Close"].pct_change()

# %%
apple_stock
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.724579  \
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  177.443542
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.723602
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  169.840240
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.008102
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  130.959961
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.142441
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.179688
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.725311
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.043121
#
#                Volume  Daily_Return
# Date
# 2022-01-03  104487900           NaN
# ...

# %%
samsung_stock
# Out:
#                  Open       High        Low      Close     Adj Close  Volume
# Date
# 2022-01-03  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0  \
# 2022-01-04  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# 2022-01-05  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# 2022-01-06  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# 2022-01-07  57.750000  57.750000  57.750000  57.750000  3.846411e+08       0
# ...               ...        ...        ...        ...           ...     ...
# 2022-12-23  40.599899  40.599899  40.599899  40.599899 -1.242691e+06       0
# 2022-12-27  40.599899  40.599899  40.599899  40.599899 -1.242691e+06       0
# 2022-12-28  40.599899  40.599899  40.599899  40.599899  1.574692e+05       0
# 2022-12-29  40.599899  40.599899  40.599899  40.599899  1.574692e+05       0
# 2022-12-30  40.599899  40.599899  40.599899  40.599899  1.574692e+05       0
#
#             Daily_Return
# Date
# ...

# %%
plt.plot(apple_stock["Daily_Return"], color='orange', label="Apple")  
plt.plot(samsung_stock["Daily_Return"], color='blue', label="Samsung")  

plt.title("Apple vs Samsung Returns")
plt.xlabel("Date")
plt.ylabel("Daily Return")
plt.legend() 
plt.show()

# %% [markdown]
# ## Calculation Simple Moving Averages

# %%
apple_stock["50_MA"] = apple_stock["Adj Close"].rolling(window = 50).mean()
samsung_stock["50_MA"] = samsung_stock["Adj Close"].rolling(window = 50).mean()

# %%
# Creating subplots with 2 rows and 1 column
fig, axs = plt.subplots(2, 1, figsize=(10, 12))

# First subplot
axs[0].plot(apple_stock["Adj Close"], label="Adj Close", color='green')
axs[0].plot(apple_stock["50_MA"], label = "50-day MA", color='orange')
axs[0].set_title("Apple Stock Simple Moving Average")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Price ($)")
axs[0].legend()

# Second subplot
axs[1].plot(samsung_stock["Adj Close"], label="Adj Close", color='blue')
axs[1].plot(samsung_stock["50_MA"], label = "50-day MA", color='orange')
axs[1].set_title("Samsung Stock Simple Moving Average")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("Price ($)")
axs[1].legend()

# Adjust layout to prevent overlapping of subplots

# Show the plots
plt.show()

# %% [markdown]
# ## Stock Performance Analysis: Apple vs. Samsung

# %%
apple_highest = apple_stock["Close"].max()
apple_lowest = apple_stock["Close"].min()
samsung_highest = samsung_stock["Close"].max()
samsung_lowest = samsung_stock["Close"].min()

# Calculate percentage returns (using closing prices)
apple_new_return = ((apple_highest - apple_lowest) / apple_lowest) * 100
samsung_new_return = ((samsung_highest - samsung_lowest) / samsung_lowest) * 100

# Print the results
print("Apple Highest Price:", apple_highest)
print("Apple Lowest Price:", apple_lowest)
print("Apple Return:", apple_new_return, "%")

print("\nSamsung Highest Price:", samsung_highest)
print("Samsung Loweest Price:", samsung_lowest)
print("Samsung Return:", samsung_new_return, "%")


if apple_new_return > samsung_new_return:
    best_stock = "Apple"
else:
    best_stock = "Samsung"
print("\nThe best performing stock with the highest return is:", best_stock)
# Out:
# Apple Highest Price: 182.00999450683594
# Apple Lowest Price: 126.04000091552734
# Apple Return: 44.406532199900546 %
#
# Samsung Highest Price: 57.75
# Samsung Loweest Price: 40.59989929199219
# Samsung Return: 42.241732139937724 %
#
# The best performing stock with the highest return is: Apple
